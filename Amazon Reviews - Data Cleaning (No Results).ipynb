# %%
-from pyspark.sql.functions import lit

# Load the three different product categories: Video Games, Books, and Home and Kitchen
# Add a category column for all three data sets

df1 = spark.sql("select * from default.video_games_5")
df1 = df1.withColumn("category", lit("video_games"))
                     
df2 = spark.sql("select * from default.books_5_small")
df2 = df2.withColumn("category", lit("books"))
                     
df3 = spark.sql("select * from default.home_and_kitchen_5_small")
df3 = df3.withColumn("category", lit("home_kitchen"))

# Combine the three data sets into one data set for data cleaning

df = df1.union(df2).union(df3)

# There are 3,487,331 observations and 12 original features and 1 added feature                     

print((df.count(), len(df.columns)))

# %%
# Quick summary statistics of Amazon Reviews data set

df.describe().show()

# %%
# Display raw amazon review data

display(df)

# %%
# Drop duplicates using a subset of features reviewerID and asin
# Number of duplicated observations removed is approximately 8.3 % (288,157 = 3,487,331 - 3,199,174)

print("Before duplication removal: ", df.count())
df_distinct = df.dropDuplicates(["reviewerID", "asin"])
print("After duplication removal: ", df_distinct.count())

# %%
# Convert Unix timestamp to readable date

from pyspark.sql.functions import from_unixtime, to_date

df_date = df_distinct.withColumn("reviewTime", to_date(from_unixtime(df_distinct.unixReviewTime))).drop("unixReviewTime")

# %%
# Fill in the empty vote column with 0, and convert it to numeric type

from pyspark.sql.types import *

df_fill_vote = df_date.withColumn("vote", df_date.vote.cast(IntegerType())).fillna(0, subset = ["vote"])

# %%
# Install nltk

! pip install nltk

# Install Spark NLP

! pip install --ignore-installed spark-nlp==2.4.5

# %%
# Adapted from https://github.com/maobedkova/TopicModelling_PySpark_SparkNLP/blob/master/Topic_Modelling_with_PySpark_and_Spark_NLP.ipynb
# Converts reviewText data into Spark NLP annotation format

from sparknlp.base import DocumentAssembler

documentAssembler = DocumentAssembler() \
                    .setInputCol("reviewText") \
                    .setOutputCol("reviewDocument")

# %%
# Tokenize data using Tokenizer

from sparknlp.annotator import Tokenizer

tokenizer = Tokenizer() \
            .setInputCols(["reviewDocument"]) \
            .setOutputCol("reviewTokenized")

# %%
# Download stop words from nltk package

import nltk
nltk.download("stopwords")

from nltk.corpus import stopwords

eng_stopwords = stopwords.words("english")

# %%
# Remove stop words 

from sparknlp.annotator import StopWordsCleaner

stopwords_cleaner = StopWordsCleaner() \
                    .setInputCols(["reviewTokenized"]) \
                    .setOutputCol("reviewSWRemoved") \
                    .setStopWords(eng_stopwords)

# %%
# Normalize data to lowercase

from sparknlp.annotator import Normalizer

normalizer = Normalizer() \
             .setInputCols(["reviewSWRemoved"]) \
             .setOutputCol("reviewNormalized") \
             .setLowercase(True)

# %%
# Lemmatize data

from sparknlp.annotator import LemmatizerModel

lemmatizer = LemmatizerModel.pretrained() \
             .setInputCols(["reviewNormalized"]) \
             .setOutputCol("reviewUnigrams")

# %%
# Create n-grams

from sparknlp.annotator import NGramGenerator

ngrammer = NGramGenerator() \
           .setInputCols(["reviewUnigrams"]) \
           .setOutputCol("reviewNgrams") \
           .setN(2) \
           .setEnableCumulative(True) \
           .setDelimiter('_')

# %%
# Use Part-of-Speech (POS) tagger

from sparknlp.annotator import PerceptronModel

pos_tagger = PerceptronModel.pretrained("pos_anc") \
             .setInputCols(["reviewDocument", "reviewUnigrams"]) \
             .setOutputCol("reviewPOS")

# %%
# Transform data with Finisher

from sparknlp.base import Finisher

finisher = Finisher() \
           .setInputCols(["reviewUnigrams", "reviewNgrams", "reviewPOS"])

# %%
# Create a Preprocessing Pipeline

from pyspark.ml import Pipeline

pipeline = Pipeline() \
           .setStages([documentAssembler,
                      tokenizer,
                      stopwords_cleaner,
                      normalizer,
                      lemmatizer,
                      ngrammer,
                      pos_tagger,
                      finisher])

# %%
# Fit the pipeline to training data

pipeline_fit = pipeline.fit(df_fill_vote)
df_transformed = pipeline_fit.transform(df_fill_vote)
df_transformed.show(5)

# %%
display(df_transformed)

# %%
# Join POS Tags

from pyspark.sql import types as T
from pyspark.sql import functions as F

udf_join_arr = F.udf(lambda x: " ".join(x), T.StringType())
df_transformed = df_transformed.withColumn("finished_reviewPOS", udf_join_arr(F.col("finished_reviewPOS")))

# %%
# Converts POS Tags into Spark NLP annotation format 

pos_documentAssembler = DocumentAssembler() \
                        .setInputCol("finished_reviewPOS") \
                        .setOutputCol("posDocument")

# %%
# Tokenize POS tags using Tokenizer

pos_tokenizer = Tokenizer() \
                .setInputCols(["posDocument"]) \
                .setOutputCol("posTokenized")

# %%
# Generate N-grams for POS Tags

pos_ngrammer = NGramGenerator() \
               .setInputCols(["posTokenized"]) \
               .setOutputCol("posNgrams") \
               .setN(2) \
               .setEnableCumulative(True) \
               .setDelimiter("_")

# %%
# Transform POS Tags with Finisher

pos_finisher = Finisher() \
               .setInputCols(["posTokenized", "posNgrams"])

# %%
# Create a Preprocessing Pipeline

pos_pipeline = Pipeline() \
               .setStages([pos_documentAssembler,
                          pos_tokenizer,
                          pos_ngrammer,
                          pos_finisher])

# %%
# Fit the Pipeline to Training Data

df_processed = pos_pipeline.fit(df_transformed).transform(df_transformed)
df_processed.show(5)

# %%
df_processed.columns

# %%
df_processed.select("finished_reviewUnigrams", "finished_posTokenized").limit(5).show()

# %%
df_processed.select("finished_reviewNgrams", "finished_posNgrams").limit(5).show()

# %%
# Create Function to Filter Out POS Tags

def filter_pos(words, pos_tags):
    return [word for word, pos in zip(words, pos_tags) 
            if pos in ["JJ", "NN", "NNS", "VB", "VBP"]]

udf_filter_pos = F.udf(filter_pos, T.ArrayType(T.StringType()))

# %%
df_processed = df_processed.withColumn("filtered_unigrams",
                                               udf_filter_pos(F.col("finished_reviewUnigrams"), 
                                                              F.col("finished_posTokenized")))

# %%
df_processed.select("filtered_unigrams").limit(5).show(truncate = 90)

# %%
def filter_pos_combs(words, pos_tags):
  return [word for word, pos in zip(words, pos_tags)
         if (len(pos.split("_")) == 2 and \
            pos.split("_")[0] in ["JJ", "NN", "NNS", "VB", "VBP"] and \
            pos.split("_")[1] in ["JJ", "NN", "NNS"])]

udf_filter_pos_combs = F.udf(filter_pos_combs, T.ArrayType(T.StringType()))

# %%
df_processed = df_processed.withColumn("filtered_ngrams",
                                      udf_filter_pos_combs(F.col("finished_reviewNgrams"), F.col("finished_posNgrams")))

# %%
df_processed.select("filtered_ngrams").limit(5).show(truncate = 90)

# %%
#Combine Unigram and Ngrams

from pyspark.sql.functions import concat

df_processed = df_processed.withColumn("reviewFinal",
                                          concat(F.col("filtered_unigrams"),
                                                 F.col("filtered_ngrams")))

# %%
# Dropping temporary columns, and cache results (note that cache is also a lazy operation)

df_cleaned = df_processed.drop("finished_reviewUnigrams",
 "finished_reviewNgrams",
 "finished_reviewPOS",
 "finished_posTokenized",
 "finished_posNgrams",
 ).cache()

display(df_cleaned)

# %%
df_cleaned.printSchema()

# %%
#Convert filter_unigrams array to string for sentiment analysis
df_cleaned = df_cleaned.withColumn("reviewString", F.concat_ws(" ", "filtered_unigrams"))

# %%
display(df_cleaned)

# %%
from pyspark.sql.types import FloatType

from textblob import TextBlob

def sentiment_analysis(text):
  return TextBlob(text).sentiment.polarity

sentiment_analysis_udf = udf(sentiment_analysis, FloatType())

# %%
df_cleaned = df_cleaned.withColumn("sentiment_score", sentiment_analysis_udf(df_cleaned["reviewString"]))
df_cleaned.show(5, True)

# %%
# Review Length
df_cleaned = df_cleaned.withColumn("reviewLength", F.length("reviewString"))

# %%
# Review Word Count
df_cleaned = df_cleaned.withColumn("reviewWordcount", F.size(F.split(F.col("reviewString"), " ")))

# %%
display(df_cleaned)

# %%
df_cleaned.columns

# %%
#Convert df_cleaned dataframe to sql table
df_cleaned.createOrReplaceTempView("df_cleaned_table")

# %%
# %sql
create table mma2021w_islington.df_cleaned as
select reviewID,
 overall,
 vote,
 verified,
 reviewTime,
 reviewerID,
 asin,
 label,
 category,
 reviewString,
 sentiment_score,
 reviewLength,
 reviewWordcount from df_cleaned_table

# %%
# Create a cleaned dataframe for books with label = 1
df_books_cleaned_1 = df_cleaned.filter((F.col("category") == "books") & (F.col("label") == 1))

# %%
display(df_books_cleaned_1).show(5)

# %%
counts_books_1 = df_books_cleaned_1.select(F.explode("filtered_unigrams").alias("col")).groupBy("col").count().sort(F.desc("count")).collect()

# %%
display(counts_books_1)

# %%
counts_books_2grams_1 = df_books_cleaned_1.select(F.explode("filtered_ngrams").alias("col")).groupBy("col").count().sort(F.desc("count")).collect()

# %%
display(counts_books_2grams_1).show(10)

# %%
from pyspark.ml.feature import CountVectorizer

tfizer = CountVectorizer(inputCol = "reviewFinal", outputCol = "tf_Features")
tf_model = tfizer.fit(df_books_cleaned_1)
tf_result = tf_model.transform(df_books_cleaned_1)

# %%
from pyspark.ml.feature import IDF

idfizer = IDF(inputCol = "tf_Features", outputCol = "tf_idf_features")
idf_model = idfizer.fit(tf_result)
tfidf_result = idf_model.transform(tf_result)

# %%
from pyspark.ml.clustering import LDA

num_topics = 8
max_iter = 10

lda = LDA(k = num_topics, maxIter = max_iter, featuresCol = "tf_idf_features")
lda_model = lda.fit(tfidf_result)

# %%
vocab = tf_model.vocabulary

def get_words(token_list):
  return [vocab[token_id] for token_id in token_list]

udf_to_words = F.udf(get_words, T.ArrayType(T.StringType()))

# %%
num_top_words = 8

topics = lda_model.describeTopics(num_top_words).withColumn("topicWords", udf_to_words(F.col("termIndices")))
topics.select("topic", "topicWords").show(truncate = 90)

# %%
# Create a cleaned dataframe for books with label = 1
df_books_cleaned_0 = df_cleaned.filter((F.col("category") == "books") & (F.col("label") == 0))

# %%
display(df_books_cleaned_0).show(5)

# %%
counts_books_0 = df_books_cleaned_0.select(F.explode("filtered_unigrams").alias("col")).groupBy("col").count().sort(F.desc("count")).collect()

# %%
display(counts_books_0)

# %%
counts_books_2grams_0 = df_books_cleaned_0.select(F.explode("filtered_ngrams").alias("col")).groupBy("col").count().sort(F.desc("count")).collect()

# %%
display(counts_books_2grams_0).show(10)

# %%
from pyspark.ml.feature import CountVectorizer

tfizer = CountVectorizer(inputCol = "reviewFinal", outputCol = "tf_Features")
tf_model = tfizer.fit(df_books_cleaned_0)
tf_result = tf_model.transform(df_books_cleaned_0)

# %%
from pyspark.ml.feature import IDF

idfizer = IDF(inputCol = "tf_Features", outputCol = "tf_idf_features")
idf_model = idfizer.fit(tf_result)
tfidf_result = idf_model.transform(tf_result)

# %%
from pyspark.ml.clustering import LDA

num_topics = 8
max_iter = 10

lda = LDA(k = num_topics, maxIter = max_iter, featuresCol = "tf_idf_features")
lda_model = lda.fit(tfidf_result)

# %%
vocab = tf_model.vocabulary

def get_words(token_list):
  return [vocab[token_id] for token_id in token_list]

udf_to_words = F.udf(get_words, T.ArrayType(T.StringType()))

# %%
num_top_words = 8

topics = lda_model.describeTopics(num_top_words).withColumn("topicWords", udf_to_words(F.col("termIndices")))
topics.select("topic", "topicWords").show(truncate = 90)

# %%
# Create a cleaned dataframe for home & kitchen with label = 1
df_home_kitchen_cleaned_1 = df_cleaned.filter((F.col("category") == "home_kitchen") & (F.col("label") == 1))

# %%
counts_home_kitchen_1 = df_home_kitchen_cleaned_1.select(F.explode("filtered_unigrams").alias("col")).groupBy("col").count().sort(F.desc("count")).collect()

# %%
display(counts_home_kitchen_1)

# %%
counts_home_kitchen_2grams_1 = df_home_kitchen_cleaned_1.select(F.explode("filtered_ngrams").alias("col")).groupBy("col").count().sort(F.desc("count")).collect()

# %%
display(counts_home_kitchen_2grams_1)

# %%
from pyspark.ml.feature import CountVectorizer

tfizer = CountVectorizer(inputCol = "reviewFinal", outputCol = "tf_Features")
tf_model = tfizer.fit(df_home_kitchen_cleaned_1)
tf_result = tf_model.transform(df_home_kitchen_cleaned_1)

# %%
from pyspark.ml.feature import IDF

idfizer = IDF(inputCol = "tf_Features", outputCol = "tf_idf_features")
idf_model = idfizer.fit(tf_result)
tfidf_result = idf_model.transform(tf_result)

# %%
from pyspark.ml.clustering import LDA

num_topics = 8
max_iter = 10

lda = LDA(k = num_topics, maxIter = max_iter, featuresCol = "tf_idf_features")
lda_model = lda.fit(tfidf_result)

# %%
vocab = tf_model.vocabulary

def get_words(token_list):
  return [vocab[token_id] for token_id in token_list]

udf_to_words = F.udf(get_words, T.ArrayType(T.StringType()))

# %%
num_top_words = 8

topics = lda_model.describeTopics(num_top_words).withColumn("topicWords", udf_to_words(F.col("termIndices")))
topics.select("topic", "topicWords").show(truncate = 90)

# %%
# Create a cleaned dataframe for home & kitchen with label = 1
df_home_kitchen_cleaned_0 = df_cleaned.filter((F.col("category") == "home_kitchen") & (F.col("label") == 0))

# %%
counts_home_kitchen_0 = df_home_kitchen_cleaned_0.select(F.explode("filtered_unigrams").alias("col")).groupBy("col").count().sort(F.desc("count")).collect()

# %%
display(counts_home_kitchen_0)

# %%
counts_home_kitchen_2grams_0 = df_home_kitchen_cleaned_0.select(F.explode("filtered_ngrams").alias("col")).groupBy("col").count().sort(F.desc("count")).collect()

# %%
display(counts_home_kitchen_2grams_0)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col</th><th>count</th></tr></thead><tbody><tr><td>work_great</td><td>71472</td></tr><tr><td>easy_use</td><td>33814</td></tr><tr><td>good_quality</td><td>25876</td></tr><tr><td>look_great</td><td>25420</td></tr><tr><td>great_product</td><td>24868</td></tr><tr><td>great_price</td><td>17957</td></tr><tr><td>easy_clean</td><td>16802</td></tr><tr><td>look_nice</td><td>15268</td></tr><tr><td>perfect_size</td><td>14416</td></tr><tr><td>work_fine</td><td>14286</td></tr><tr><td>long_time</td><td>14176</td></tr><tr><td>look_good</td><td>13345</td></tr><tr><td>good_price</td><td>13069</td></tr><tr><td>stainless_steel</td><td>12732</td></tr><tr><td>coffee_maker</td><td>12565</td></tr><tr><td>ive_use</td><td>12553</td></tr><tr><td>last_long</td><td>12003</td></tr><tr><td>high_quality</td><td>11937</td></tr><tr><td>year_old</td><td>11877</td></tr><tr><td>make_sure</td><td>11856</td></tr><tr><td>good_product</td><td>11807</td></tr><tr><td>great_quality</td><td>11308</td></tr><tr><td>easy_put</td><td>9836</td></tr><tr><td>easy_assemble</td><td>9629</td></tr><tr><td>make_easy</td><td>9459</td></tr><tr><td>happy_purchase</td><td>9257</td></tr><tr><td>use_time</td><td>8920</td></tr><tr><td>make_great</td><td>8859</td></tr><tr><td>first_time</td><td>8594</td></tr><tr><td>last_year</td><td>8529</td></tr><tr><td>give_star</td><td>8436</td></tr><tr><td>love_love</td><td>8331</td></tr><tr><td>heavy_duty</td><td>8057</td></tr><tr><td>cast_iron</td><td>7935</td></tr><tr><td>easy_install</td><td>7551</td></tr><tr><td>im_happy</td><td>7272</td></tr><tr><td>time_use</td><td>7193</td></tr><tr><td>read_review</td><td>7013</td></tr><tr><td>much_easy</td><td>6969</td></tr><tr><td>use_make</td><td>6940</td></tr><tr><td>recommend_product</td><td>6889</td></tr><tr><td>work_good</td><td>6844</td></tr><tr><td>im_sure</td><td>6817</td></tr><tr><td>light_weight</td><td>6748</td></tr><tr><td>great_job</td><td>6666</td></tr><tr><td>ice_cream</td><td>6523</td></tr><tr><td>make_good</td><td>6506</td></tr><tr><td>nice_look</td><td>6498</td></tr><tr><td>cup_coffee</td><td>6496</td></tr><tr><td>great_little</td><td>6489</td></tr><tr><td>get_use</td><td>6476</td></tr><tr><td>recommend_anyone</td><td>6306</td></tr><tr><td>worth_money</td><td>6168</td></tr><tr><td>paper_towel</td><td>6149</td></tr><tr><td>great_buy</td><td>6120</td></tr><tr><td>hot_water</td><td>5869</td></tr><tr><td>good_size</td><td>5841</td></tr><tr><td>right_size</td><td>5816</td></tr><tr><td>many_year</td><td>5788</td></tr><tr><td>quality_product</td><td>5711</td></tr><tr><td>little_bit</td><td>5591</td></tr><tr><td>nice_quality</td><td>5556</td></tr><tr><td>great_value</td><td>5492</td></tr><tr><td>shower_curtain</td><td>5491</td></tr><tr><td>love_use</td><td>5462</td></tr><tr><td>get_hot</td><td>5330</td></tr><tr><td>good_value</td><td>5313</td></tr><tr><td>cut_board</td><td>5270</td></tr><tr><td>live_room</td><td>5176</td></tr><tr><td>waste_money</td><td>5116</td></tr><tr><td>year_use</td><td>5101</td></tr><tr><td>good_job</td><td>5091</td></tr><tr><td>buy_gift</td><td>5026</td></tr><tr><td>hold_lot</td><td>4863</td></tr><tr><td>several_time</td><td>4856</td></tr><tr><td>good_thing</td><td>4719</td></tr><tr><td>super_easy</td><td>4712</td></tr><tr><td>keep_coffee</td><td>4696</td></tr><tr><td>excellent_product</td><td>4651</td></tr><tr><td>good_buy</td><td>4644</td></tr><tr><td>worth_price</td><td>4612</td></tr><tr><td>im_glad</td><td>4594</td></tr><tr><td>serve_purpose</td><td>4532</td></tr><tr><td>great_size</td><td>4518</td></tr><tr><td>give_gift</td><td>4440</td></tr><tr><td>great_use</td><td>4354</td></tr><tr><td>get_job</td><td>4284</td></tr><tr><td>product_work</td><td>4236</td></tr><tr><td>take_much</td><td>4169</td></tr><tr><td>stop_work</td><td>4117</td></tr><tr><td>go_wrong</td><td>4086</td></tr><tr><td>cant_beat</td><td>4074</td></tr><tr><td>use_year</td><td>4071</td></tr> ...

# %%
from pyspark.ml.feature import CountVectorizer

tfizer = CountVectorizer(inputCol = "reviewFinal", outputCol = "tf_Features")
tf_model = tfizer.fit(df_home_kitchen_cleaned_0)
tf_result = tf_model.transform(df_home_kitchen_cleaned_0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.feature import IDF

idfizer = IDF(inputCol = "tf_Features", outputCol = "tf_idf_features")
idf_model = idfizer.fit(tf_result)
tfidf_result = idf_model.transform(tf_result)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.clustering import LDA

num_topics = 8
max_iter = 10

lda = LDA(k = num_topics, maxIter = max_iter, featuresCol = "tf_idf_features")
lda_model = lda.fit(tfidf_result)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
vocab = tf_model.vocabulary

def get_words(token_list):
  return [vocab[token_id] for token_id in token_list]

udf_to_words = F.udf(get_words, T.ArrayType(T.StringType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
num_top_words = 8

topics = lda_model.describeTopics(num_top_words).withColumn("topicWords", udf_to_words(F.col("termIndices")))
topics.select("topic", "topicWords").show(truncate = 90)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-----------------------------------------------------+
# topic|                                           topicWords|
# +-----+-----------------------------------------------------+
#     0|      [great, tea, get, use, make, work, water, nice]|
#     1|[pillow, product, vacuum, use, get, great, look, buy]|
#     2|    [pan, cook, use, good, great, love, egg, quality]|
#     3|      [work, use, great, bake, love, bowl, make, buy]|
#     4|     [knife, good, use, iron, love, hold, easy, time]|
#     5| [coffee, filter, look, good, use, make, maker, work]|
#     6|   [fan, use, small, glass, perfect, air, work, make]|
#     7|    [love, clock, use, get, easy, time, great, water]|
# +-----+-----------------------------------------------------+
#
# </div>

# %%
# Create a cleaned dataframe for home & kitchen with label = 1
df_video_games_cleaned_1 = df_cleaned.filter((F.col("category") == "video_games") & (F.col("label") == 1))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
counts_video_games_1 = df_video_games_cleaned_1.select(F.explode("filtered_unigrams").alias("col")).groupBy("col").count().sort(F.desc("count")).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(counts_video_games_1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col</th><th>count</th></tr></thead><tbody><tr><td>game</td><td>558511</td></tr><tr><td>play</td><td>169729</td></tr><tr><td>get</td><td>154221</td></tr><tr><td>good</td><td>101725</td></tr><tr><td>time</td><td>98473</td></tr><tr><td>make</td><td>92805</td></tr><tr><td>go</td><td>78342</td></tr><tr><td>use</td><td>72834</td></tr><tr><td>great</td><td>62990</td></tr><tr><td>character</td><td>62253</td></tr><tr><td>fun</td><td>60153</td></tr><tr><td>new</td><td>56637</td></tr><tr><td>look</td><td>54761</td></tr><tr><td>take</td><td>54439</td></tr><tr><td>thing</td><td>54266</td></tr><tr><td>much</td><td>48985</td></tr><tr><td>find</td><td>48413</td></tr><tr><td>see</td><td>48366</td></tr><tr><td>way</td><td>47931</td></tr><tr><td>story</td><td>47626</td></tr><tr><td>feel</td><td>47351</td></tr><tr><td>want</td><td>47249</td></tr><tr><td>say</td><td>46985</td></tr><tr><td>buy</td><td>46871</td></tr><tr><td>graphics</td><td>46349</td></tr><tr><td>level</td><td>45933</td></tr><tr><td>think</td><td>44278</td></tr><tr><td>first</td><td>43585</td></tr><tr><td>give</td><td>42123</td></tr><tr><td>lot</td><td>41690</td></tr><tr><td>player</td><td>41244</td></tr><tr><td>many</td><td>39059</td></tr><tr><td>im</td><td>37693</td></tr><tr><td>work</td><td>37096</td></tr><tr><td>come</td><td>35652</td></tr><tr><td>p</td><td>35291</td></tr><tr><td>try</td><td>35219</td></tr><tr><td>system</td><td>35022</td></tr><tr><td>know</td><td>33862</td></tr><tr><td>control</td><td>33745</td></tr><tr><td>people</td><td>33441</td></tr><tr><td>bad</td><td>33351</td></tr><tr><td>need</td><td>32047</td></tr><tr><td>gameplay</td><td>31998</td></tr><tr><td>love</td><td>31507</td></tr><tr><td>little</td><td>30820</td></tr><tr><td>enemy</td><td>30725</td></tr><tr><td>mode</td><td>30144</td></tr><tr><td>different</td><td>30003</td></tr><tr><td>start</td><td>28841</td></tr><tr><td>ive</td><td>28517</td></tr><tr><td>point</td><td>27869</td></tr><tr><td>sound</td><td>27427</td></tr><tr><td>year</td><td>27413</td></tr><tr><td>run</td><td>27227</td></tr><tr><td>seem</td><td>26621</td></tr><tr><td>hour</td><td>26538</td></tr><tr><td>
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.feature import IDF

idfizer = IDF(inputCol = "tf_Features", outputCol = "tf_idf_features")
idf_model = idfizer.fit(tf_result)
tfidf_result = idf_model.transform(tf_result)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.clustering import LDA

num_topics = 8
max_iter = 10

lda = LDA(k = num_topics, maxIter = max_iter, featuresCol = "tf_idf_features")
lda_model = lda.fit(tfidf_result)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
vocab = tf_model.vocabulary

def get_words(token_list):
  return [vocab[token_id] for token_id in token_list]

udf_to_words = F.udf(get_words, T.ArrayType(T.StringType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
num_top_words = 8

topics = lda_model.describeTopics(num_top_words).withColumn("topicWords", udf_to_words(F.col("termIndices")))
topics.select("topic", "topicWords").show(truncate = 90)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-------------------------------------------------------------+
# topic|                                                   topicWords|
# +-----+-------------------------------------------------------------+
#     0|   [character, story, enemy, level, battle, time, game, play]|
#     1|               [car, race, mode, game, get, make, time, good]|
#     2|       [wii, u, controller, mode, get, gamecube, play, sonic]|
#     3|  [mouse, keyboard, sims, song, key, button, controller, use]|
#     4|[mario, ds, nintendo, super, pokemon, super_mario, wii, kart]|
#     5|          [player, level, game, try, weapon, play, team, get]|
#     6|   [headset, p, xbox, controller, psp, console, sound, cable]|
#     7|      [halo, play, xbox, mission, online, guitar, p, version]|
# +-----+-------------------------------------------------------------+
#
# </div>

# %%
# Create a cleaned dataframe for home & kitchen with label = 1
df_video_games_cleaned_0 = df_cleaned.filter((F.col("category") == "video_games") & (F.col("label") == 0))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
counts_video_games_0 = df_video_games_cleaned_0.select(F.explode("filtered_unigrams").alias("col")).groupBy("col").count().sort(F.desc("count")).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(counts_video_games_0)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col</th><th>count</th></tr></thead><tbody><tr><td>game</td><td>601818</td></tr><tr><td>play</td><td>193263</td></tr><tr><td>get</td><td>159670</td></tr><tr><td>good</td><td>147828</td></tr><tr><td>great</td><td>127033</td></tr><tr><td>time</td><td>93046</td></tr><tr><td>fun</td><td>83890</td></tr><tr><td>make</td><td>82711</td></tr><tr><td>use</td><td>80718</td></tr><tr><td>love</td><td>71810</td></tr><tr><td>buy</td><td>66303</td></tr><tr><td>go</td><td>66192</td></tr><tr><td>work</td><td>65254</td></tr><tr><td>story</td><td>52304</td></tr><tr><td>look</td><td>51672</td></tr><tr><td>character</td><td>50519</td></tr><tr><td>new</td><td>49740</td></tr><tr><td>graphics</td><td>48102</td></tr><tr><td>thing</td><td>47837</td></tr><tr><td>much</td><td>47536</td></tr><tr><td>feel</td><td>45908</td></tr><tr><td>say</td><td>45227</td></tr><tr><td>take</td><td>45072</td></tr><tr><td>want</td><td>43410</td></tr><tr><td>lot</td><td>43359</td></tr><tr><td>find</td><td>42189</td></tr><tr><td>think</td
tr><tr><td>im_sure</td><td>2690</td></tr><tr><td>game_take</td><td>2674</td></tr><tr><td>graphics_good</td><td>2670</td></tr><tr><td>great_price</td><td>2655</td></tr><tr><td>open_world</td><td>2654</td></tr><tr><td>cut_scene</td><td>2615</td></tr><tr><td>give_star</td><td>2610</td></tr><tr><td>little_bit</td><td>2578</td></tr><tr><td>type_game</td><td>2563</td></tr><tr><td>think_game</td><td>2549</td></tr><tr><td>game_work</td><td>2498</td></tr><tr><td>game_p</td><td>2465</td></tr><tr><td>graphics_great</td><td>2458</td></tr><tr><td>game_buy</td><td>2456</td></tr><tr><td>first_person</td><td>2445</td></tr><tr><td>thing_game</td><td>2445</td></tr><tr><td>story_mode</td><td>2443</td></tr><tr><td>assassin_creed</td><td>2423</td></tr><tr><td>time_game</td><td>2411</td></tr><tr><td>kid_love</td><td>2406</td></tr><tr><td>look_good</td><td>2403</td></tr><tr><td>good_graphics</td><td>2387</td></tr><tr><td>person_shooter</td><td>2382</td></tr><tr><td>want_play</td><td>2345</td></tr><tr><td>bad_game</td><td>2344</td></tr><tr><td>mario_kart</td><td>2321</td></tr><tr><td>metal_gear</td><td>2301</td></tr><tr><td>find_game</td><td>2300</td></tr><tr><td>game_worth</td><td>2299</td></tr><tr><td>old_game</td><td>2298</td></tr><tr><td>love_play</t ...

# %%
from pyspark.ml.feature import CountVectorizer

tfizer = CountVectorizer(inputCol = "reviewFinal", outputCol = "tf_Features")
tf_model = tfizer.fit(df_video_games_cleaned_0)
tf_result = tf_model.transform(df_video_games_cleaned_0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.feature import IDF

idfizer = IDF(inputCol = "tf_Features", outputCol = "tf_idf_features")
idf_model = idfizer.fit(tf_result)
tfidf_result = idf_model.transform(tf_result)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.clustering import LDA

num_topics = 8
max_iter = 10

lda = LDA(k = num_topics, maxIter = max_iter, featuresCol = "tf_idf_features")
lda_model = lda.fit(tfidf_result)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
vocab = tf_model.vocabulary

def get_words(token_list):
  return [vocab[token_id] for token_id in token_list]

udf_to_words = F.udf(get_words, T.ArrayType(T.StringType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
num_top_words = 8

topics = lda_model.describeTopics(num_top_words).withColumn("topicWords", udf_to_words(F.col("termIndices")))
topics.select("topic", "topicWords").show(truncate = 90)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------------------------------------------------------------------+
# topic|                                                          topicWords|
# +-----+--------------------------------------------------------------------+
#     0|                  [game, play, get, fun, story, good, character, go]|
#     1|                [game, play, get, time, good, make, character, love]|
#     2|               [game, fun, play, get, time, character, level, story]|
#     3|           [controller, race, game, car, use, work, button, pokemon]|
#     4|          [controller, keyboard, game, sonic, p, buy, good, version]|
#     5|                [game, good, play, get, controller, use, awesome, p]|
#     6|[great, work, headset, sound, product, cable, work_great, excellent]|
#     7|                   [mouse, game, button, get, use, time, play, good]|
# +-----+--------------------------------------------------------------------+
#
# </div>

# %%
#Count of each overall rating 

#from pyspark.sql.functions import col
#df_cleaned.groupBy("overall").count().orderBy(col("overall").asc()).show()

# %%
#The most common product IDs

#df.groupBy("asin").count().orderBy(col("count").desc()).show(10)
